# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SBSPS-Challenge-10952-1692817135/blob/main/CollegePlacementSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-dc303a1e-b506-4785-b5d4-ab84f5da6065" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc303a1e-b506-4785-b5d4-ab84f5da6065">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Installing Gradio

# %%
# !pip install gradio

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import gradio as gr
import pandas as pd

# %% [markdown]
# # Importing the excel file

# %%
df=pd.read_excel("Placement Data 2.xlsx")

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#    Enrollment No. Gender  10th % SSC Board  12th %            CERTIFICATION  \
# 0               1      M   67.00  MP Board   91.00     AWS Cloud Foundation
# 1               2      M   79.33      CBSE   78.33     AWS Cloud Foundation
# 2               3      M   65.00      CBSE   68.00  PCAP : Python essential
# 3               4      M   56.00      CBSE   52.00  PCAP : Python essential
# 4               5      M   85.80      CBSE   73.60  PCAP : Python essential
#
#    Degree % Degree stream Work exp specialisation   CGPA      status  \
# 0     58.00            CS       No       C , Java  5.880  Not Placed
# 1     77.48          AIML      Yes   C++ , Python  6.628  Not Placed
# 2     64.00            CS       No   C++ , Python  5.780  Not Placed
# 3     52.00          AIML       No       C , Java  5.943      Placed
# 4     73.30            CD       No   C++ , Python  5.550  Not Placed
#
#    Package(LPA) name of company               SKILLS  No_Of_Internships
# ...

# %%
df.shape
# Out:
# (215, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Enrollment No.     215 non-null    int64
#  1   Gender             215 non-null    object
#  2   10th %             215 non-null    float64
#  3   SSC Board          215 non-null    object
#  4   12th %             215 non-null    float64
#  5   CERTIFICATION      215 non-null    object
#  6   Degree %           215 non-null    float64
#  7   Degree stream      215 non-null    object
#  8   Work exp           215 non-null    object
#  9   specialisation     215 non-null    object
#  10  CGPA               215 non-null    float64
#  11  status             215 non-null    object
#  12  Package(LPA)       215 non-null    float64
#  13  name of company    215 non-null    object
#  14  SKILLS             215 non-null    object
#  15  No_Of_Internships  215 non-null    int64
# ...

# %%
df.tail()
# Out:
#      Enrollment No. Gender  10th % SSC Board  12th %         CERTIFICATION  \
# 210             211      M    80.6  MP Board    82.0  AWS Cloud Foundation
# 211             212      M    58.0  MP Board    60.0  AWS Cloud Foundation
# 212             213      M    67.0  MP Board    67.0  AWS Cloud Foundation
# 213             214      F    74.0  MP Board    66.0  AWS Cloud Foundation
# 214             215      M    62.0      CBSE    58.0  AWS Cloud Foundation
#
#      Degree % Degree stream Work exp specialisation   CGPA      status  \
# 210      77.6            CS       No   C++ , Python  7.449  Not Placed
# 211      72.0            DS       No   C++ , Python  5.362  Not Placed
# 212      73.0          AIML      Yes   C++ , Python  6.972  Not Placed
# 213      58.0           AIR       No       C , Java  6.023  Not Placed
# 214      53.0          AIML       No       C , Java  6.022      Placed
#
#      Package(LPA) name of company               SKILLS  No_Of_Internships
# ...

# %% [markdown]
# # Checking For Null Values

# %%
df.isna().sum()
# Out:
# Enrollment No.       0
# Gender               0
# 10th %               0
# SSC Board            0
# 12th %               0
# CERTIFICATION        0
# Degree %             0
# Degree stream        0
# Work exp             0
# specialisation       0
# CGPA                 0
# status               0
# Package(LPA)         0
# name of company      0
# SKILLS               0
# No_Of_Internships    0
# dtype: int64

# %% [markdown]
# #Applying descriptive statistics

# %%
df.describe()
# Out:
#        Enrollment No.      10th %      12th %    Degree %        CGPA  \
# count      215.000000  215.000000  215.000000  215.000000  215.000000
# mean       108.000000   67.303395   66.333163   66.370186    6.227819
# std         62.209324   10.827205   10.897509    7.358743    0.583338
# min          1.000000   40.890000   37.000000   50.000000    5.121000
# 25%         54.500000   60.600000   60.900000   61.000000    5.794500
# 50%        108.000000   67.000000   65.000000   66.000000    6.200000
# 75%        161.500000   75.700000   73.000000   72.000000    6.625500
# max        215.000000   89.400000   97.700000   91.000000    7.789000
#
#        Package(LPA)  No_Of_Internships
# count    215.000000         215.000000
# mean       5.096279           0.469767
# std        3.862168           0.500250
# min        2.300000           0.000000
# 25%        3.000000           0.000000
# 50%        5.000000           0.000000
# 75%        5.000000           1.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
df.head()
# Out:
#    Enrollment No. Gender  10th % SSC Board  12th %            CERTIFICATION  \
# 0               1      M   67.00  MP Board   91.00     AWS Cloud Foundation
# 1               2      M   79.33      CBSE   78.33     AWS Cloud Foundation
# 2               3      M   65.00      CBSE   68.00  PCAP : Python essential
# 3               4      M   56.00      CBSE   52.00  PCAP : Python essential
# 4               5      M   85.80      CBSE   73.60  PCAP : Python essential
#
#    Degree % Degree stream Work exp specialisation   CGPA      status  \
# 0     58.00            CS       No       C , Java  5.880  Not Placed
# 1     77.48          AIML      Yes   C++ , Python  6.628  Not Placed
# 2     64.00            CS       No   C++ , Python  5.780  Not Placed
# 3     52.00          AIML       No       C , Java  5.943      Placed
# 4     73.30            CD       No   C++ , Python  5.550  Not Placed
#
#    Package(LPA) name of company               SKILLS  No_Of_Internships
# ...

# %% [markdown]
# #BAR PLOT

# %%
x=df['Degree %']
y=df['Package(LPA)']

# %%
plt.bar(x,y,color='skyblue', width=0.5, align='center', edgecolor='gray')
plt.title("Bar plot for company with their respective package")
plt.ylim(0,15)
plt.show()

# %%
p=df["Gender"]
q=df["status"]

# %%
plt.barh(p,q, height=0.5,color='skyblue')
plt.title("status of male and female students")
plt.xlabel("status")
plt.ylabel("gender")
plt.show()

# %%
j=df['CGPA']

# %%
plt.bar(j,q,width=0.1,color='green')
plt.xlabel('CGPA')
plt.ylabel('STATUS')
plt.show()

# %% [markdown]
# # PIE CHART

# %%
plt.figure(figsize=(13,13))
a=df['name of company'].value_counts()
labels = df['name of company'].unique()
plt.pie(a,labels=labels,autopct=lambda p: '{:.0f}'.format(p * sum(a) / 100))
plt.title("Pie chart for company names")
plt.show()

# %%
plt.figure(figsize=(10,10))
b=df["Degree stream"].value_counts()
label=df["Degree stream"].unique()
plt.pie(b,labels=label,autopct=lambda p: '{:.0f}'.format(p * sum(b) / 100))
plt.title("Pie chart for Degree stream of students")
plt.show()

# %% [markdown]
# # HISTOGRAM

# %%
r=df["SKILLS"]
s=df["Work exp"]

# %%
plt.hist(r)
plt.title("SKILLS")
plt.xlabel("Skill set")
plt.ylabel("range")
# Out:
# Text(0, 0.5, 'range')

# %%
plt.hist(s)
plt.title("Work experience")
plt.xlabel("experience")
plt.ylabel("range")
# Out:
# Text(0, 0.5, 'range')

# %% [markdown]
# # LINE PLOT

# %%
X=df['specialisation']
plt.plot(X, y, marker='o', linestyle='-', color='b', label='Data Points')
plt.xlabel("specialization")
plt.ylabel("expected package")
plt.legend()
plt.show()

# %% [markdown]
# # BOX PLOT

# %%
Y=df["name of company"].value_counts()
plt.boxplot(Y)
plt.title("box plot for name of company ")
plt.show()

# %%
Z=df["Package(LPA)"]
plt.boxplot(Z)
plt.title("package")
plt.ylabel("LPA")
plt.show()

# %%
data1 = df["name of company"].value_counts()
data2 = df["CGPA"].value_counts()
plt.boxplot([data1, data2])
plt.title("outliers analysis for name of company vs package")
plt.xlabel("company")
plt.ylabel("CGPA")
plt.show()

# %% [markdown]
# # Applying encoding to convert categorical data into nominal data

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()
enc
# Out:
# OrdinalEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Enrollment No.     215 non-null    int64
#  1   Gender             215 non-null    object
#  2   10th %             215 non-null    float64
#  3   SSC Board          215 non-null    object
#  4   12th %             215 non-null    float64
#  5   CERTIFICATION      215 non-null    object
#  6   Degree %           215 non-null    float64
#  7   Degree stream      215 non-null    object
#  8   Work exp           215 non-null    object
#  9   specialisation     215 non-null    object
#  10  CGPA               215 non-null    float64
#  11  status             215 non-null    object
#  12  Package(LPA)       215 non-null    float64
#  13  name of company    215 non-null    object
#  14  SKILLS             215 non-null    object
#  15  No_Of_Internships  215 non-null    int64
# ...

# %%
df['Degree stream'].unique()
# Out:
# array(['CS', 'AIML', 'CD', 'AIR', 'DS', 'IOT'], dtype=object)

# %%
df['Degree stream'] = enc.fit_transform(df[['Degree stream']])

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
new_gen = {'M' : 0, 'F' : 1}

# %%
df['Gender'] = df['Gender'].map(new_gen)

# %%
df['CERTIFICATION'].unique()
# Out:
# array(['AWS Cloud Foundation', 'PCAP : Python essential'], dtype=object)

# %%
df['CERTIFICATION'] = enc.fit_transform(df[['CERTIFICATION']])

# %%
df['Work exp'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['specialisation'] = enc.fit_transform(df[['specialisation']])

# %%
df['Work exp'] = enc.fit_transform(df[['Work exp']])

# %%
df['specialisation'].unique()
# Out:
# array([0., 1.])

# %%
df['status'].unique()
# Out:
# array(['Not Placed', 'Placed'], dtype=object)

# %%
df['status'] = enc.fit_transform(df[['status']])

# %%
df['name of company'].unique()
# Out:
# array(['XORIANT', 'QUINNOX', 'INDUS VALLEY PARTNERS', 'IGATE',
#        'HEXAWARE TECHNOLOGIES', 'MAQ SOFTWARE', 'DIRECTI', 'ATOS',
#        'MPHASIS', 'WIPRO', 'NEOSOFT TECHNOLOGIES', 'INFOSYS',
#        'RAVE TECHNOLOGIES', 'INFOGAIN', 'NUCSOFT', 'TECH MAHINDRA',
#        'MAJESCO', 'NEWGEN SOFTWARE', 'GE', 'JIO', 'GEP', 'ORACLE',
#        'LARSEN & TOUBRO', 'MORGAN STANLEY', 'INGRAM MICRO', 'TCS',
#        'ZYCUS', 'CLOVER INFOTECH', 'IBM', 'LIONBRIDGE', 'GOOGLE',
#        'BNP PARIBAS', 'MASTEK', 'HCL TECHNOLOGIES', 'RUBIQUE',
#        'TOPPR.COM', 'ECLERX', 'KPIT TECHNOLOGIES', 'BANK OF AMERICA',
#        'DELOITTE'], dtype=object)

# %%
df['name of company'] = enc.fit_transform(df[['name of company']])

# %%
df['SKILLS'].unique()
# Out:
# array(['Cloud', 'Big Data', 'Computer Networking', 'SQL'], dtype=object)

# %%
df['SKILLS'] = enc.fit_transform(df[['SKILLS']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Enrollment No.     215 non-null    int64
#  1   Gender             215 non-null    int64
#  2   10th %             215 non-null    float64
#  3   SSC Board          215 non-null    object
#  4   12th %             215 non-null    float64
#  5   CERTIFICATION      215 non-null    float64
#  6   Degree %           215 non-null    float64
#  7   Degree stream      215 non-null    float64
#  8   Work exp           215 non-null    float64
#  9   specialisation     215 non-null    float64
#  10  CGPA               215 non-null    float64
#  11  status             215 non-null    float64
#  12  Package(LPA)       215 non-null    float64
#  13  name of company    215 non-null    float64
#  14  SKILLS             215 non-null    float64
#  15  No_Of_Internships  215 non-null    int64
# ...

# %%
df.head()
# Out:
#    Enrollment No.  Gender  10th % SSC Board  12th %  CERTIFICATION  Degree %  \
# 0               1       0   67.00  MP Board   91.00            0.0     58.00
# 1               2       0   79.33      CBSE   78.33            0.0     77.48
# 2               3       0   65.00      CBSE   68.00            1.0     64.00
# 3               4       0   56.00      CBSE   52.00            1.0     52.00
# 4               5       0   85.80      CBSE   73.60            1.0     73.30
#
#    Degree stream  Work exp  specialisation   CGPA  status  Package(LPA)  \
# 0            3.0       0.0             0.0  5.880     0.0           2.7
# 1            0.0       1.0             1.0  6.628     0.0           2.7
# 2            3.0       0.0             1.0  5.780     0.0           2.7
# 3            0.0       0.0             0.0  5.943     1.0           5.0
# 4            2.0       0.0             1.0  5.550     0.0           5.0
#
#    name of company  SKILLS  No_Of_Internships
# ...

# %% [markdown]
# ## Renaming Columns

# %%
df.rename(columns = {'CERTIFICATION' : 'Certifications', 'Degree %' : 'Degree_Percentage', '10th %' : '10th_Percentage', '12th %' : '12th_Percentage', 'Work exp' : 'Work_Exp', 'status' : 'Status', 'SKILLS' : 'Skills'}, inplace=True)

# %%
df.rename(columns = {'specialisation' : 'Speacialisation'}, inplace = True)

# %%
df.rename(columns = {'name of company' : 'NOC'}, inplace = True)

# %%
df.rename(columns = {'Enrollment No.' : 'Enrollment_no', 'Degree stream' : 'Degree_Stream'}, inplace = True)

# %% [markdown]
# # Dropping Columns

# %%
df.drop(['SSC Board'], axis = 1, inplace = True)

# %%
df.drop(['Degree_Percentage'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Enrollment_no  Gender  10th_Percentage  12th_Percentage  Certifications  \
# 0              1       0            67.00            91.00             0.0
# 1              2       0            79.33            78.33             0.0
# 2              3       0            65.00            68.00             1.0
# 3              4       0            56.00            52.00             1.0
# 4              5       0            85.80            73.60             1.0
#
#    Degree_Stream  Work_Exp  Speacialisation   CGPA  Status  Package(LPA)  \
# 0            3.0       0.0              0.0  5.880     0.0           2.7
# 1            0.0       1.0              1.0  6.628     0.0           2.7
# 2            3.0       0.0              1.0  5.780     0.0           2.7
# 3            0.0       0.0              0.0  5.943     1.0           5.0
# 4            2.0       0.0              1.0  5.550     0.0           5.0
#
#     NOC  Skills  No_Of_Internships
# 0  38.0     1.0                  0
# ...

# %% [markdown]
# # Applying Descriptive Status

# %%
df.describe()
# Out:
#        Enrollment_no      Gender  10th_Percentage  12th_Percentage  \
# count     215.000000  215.000000       215.000000       215.000000
# mean      108.000000    0.353488        67.303395        66.333163
# std        62.209324    0.479168        10.827205        10.897509
# min         1.000000    0.000000        40.890000        37.000000
# 25%        54.500000    0.000000        60.600000        60.900000
# 50%       108.000000    0.000000        67.000000        65.000000
# 75%       161.500000    1.000000        75.700000        73.000000
# max       215.000000    1.000000        89.400000        97.700000
#
#        Certifications  Degree_Stream    Work_Exp  Speacialisation        CGPA  \
# count      215.000000     215.000000  215.000000       215.000000  215.000000
# mean         0.390698       2.060465    0.344186         0.558140    6.227819
# std          0.489045       1.952968    0.476211         0.497767    0.583338
# ...

# %%
df.corr()
# Out:
#                    Enrollment_no    Gender  10th_Percentage  12th_Percentage  \
# Enrollment_no           1.000000 -0.074306        -0.078155        -0.085711
# Gender                 -0.074306  1.000000         0.068969         0.021334
# 10th_Percentage        -0.078155  0.068969         1.000000         0.511472
# 12th_Percentage        -0.085711  0.021334         0.511472         1.000000
# Certifications         -0.116887  0.065945        -0.066996         0.019548
# Degree_Stream           0.066501 -0.057901         0.101153        -0.107390
# Work_Exp                0.059151 -0.085153         0.175675         0.141025
# Speacialisation        -0.046630 -0.106160         0.172536         0.241630
# CGPA                    0.022327  0.300531         0.388478         0.354823
# Status                  0.026859  0.090670        -0.607889        -0.491228
# Package(LPA)            0.306446 -0.072259        -0.047619        -0.020146
# ...

# %% [markdown]
# # Combining similar columns by their average value

# %%
df['total_percentage']=(df['10th_Percentage'] + df['12th_Percentage'])/2
df.drop(['10th_Percentage', '12th_Percentage'], axis=1, inplace=True)
df.head()
# Out:
#    Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 0              1       0             0.0            3.0       0.0
# 1              2       0             0.0            0.0       1.0
# 2              3       0             1.0            3.0       0.0
# 3              4       0             1.0            0.0       0.0
# 4              5       0             1.0            2.0       0.0
#
#    Speacialisation   CGPA  Status  Package(LPA)   NOC  Skills  \
# 0              0.0  5.880     0.0           2.7  38.0     1.0
# 1              1.0  6.628     0.0           2.7  38.0     0.0
# 2              1.0  5.780     0.0           2.7  38.0     0.0
# 3              0.0  5.943     1.0           5.0  31.0     2.0
# 4              1.0  5.550     0.0           5.0  31.0     1.0
#
#    No_Of_Internships  total_percentage
# 0                  0             79.00
# 1                  1             78.83
# 2                  0             66.50
# ...

# %% [markdown]
# #  Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
ss
# Out:
# StandardScaler()

# %%
df[['Status']]=ss.fit_transform(df[['Status']])

# %% [markdown]
# # Converting dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Enrollment_no      215 non-null    int64
#  1   Gender             215 non-null    int64
#  2   Certifications     215 non-null    float64
#  3   Degree_Stream      215 non-null    float64
#  4   Work_Exp           215 non-null    float64
#  5   Speacialisation    215 non-null    float64
#  6   CGPA               215 non-null    float64
#  7   Status             215 non-null    float64
#  8   Package(LPA)       215 non-null    float64
#  9   NOC                215 non-null    float64
#  10  Skills             215 non-null    float64
#  11  No_Of_Internships  215 non-null    int64
#  12  total_percentage   215 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 22.0 KB

# %%
df['total_percentage'] = df['total_percentage'].astype(int)

# %%
df['Certifications'] = df['Certifications'].astype(int)

# %%
df['NOC'] = df['NOC'].astype(int)

# %%
df['Status'] = df['Status'].astype(int)

# %%
df['Work_Exp'] = df['Work_Exp'].astype(int)

# %%
df['Degree_Stream'] = df['Degree_Stream'].astype(int)

# %%
df['Speacialisation'] = df['Speacialisation'].astype(int)

# %%
df['CGPA'] = df['CGPA'].astype(int)

# %%
df['Status'] = df['Status'].astype(int)

# %%
df['Skills'] = df['Skills'].astype(int)

# %%
df['total_percentage'] = df['total_percentage'].astype(int)

# %%
df['Package(LPA)']=df['Package(LPA)'].astype(int)

# %%
df['Enrollment_no'] = df['Enrollment_no'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Enrollment_no      215 non-null    int64
#  1   Gender             215 non-null    int64
#  2   Certifications     215 non-null    int64
#  3   Degree_Stream      215 non-null    int64
#  4   Work_Exp           215 non-null    int64
#  5   Speacialisation    215 non-null    int64
#  6   CGPA               215 non-null    int64
#  7   Status             215 non-null    int64
#  8   Package(LPA)       215 non-null    int64
#  9   NOC                215 non-null    int64
#  10  Skills             215 non-null    int64
#  11  No_Of_Internships  215 non-null    int64
#  12  total_percentage   215 non-null    int64
# dtypes: int64(13)
# memory usage: 22.0 KB

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
AA=df.iloc[:,df.columns !=7]
AA
# Out:
#      Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 0                1       0               0              3         0
# 1                2       0               0              0         1
# 2                3       0               1              3         0
# 3                4       0               1              0         0
# 4                5       0               1              2         0
# ..             ...     ...             ...            ...       ...
# 210            211       0               0              3         0
# 211            212       0               0              4         0
# 212            213       0               0              0         1
# 213            214       1               0              1         0
# 214            215       0               0              0         0
#
#      Speacialisation  CGPA  Status  Package(LPA)  NOC  Skills  \
# 0                  0     5       0             2   38       1
# ...

# %%
BB=df.iloc[:,7]
BB
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 210    0
# 211    0
# 212    0
# 213    0
# 214    1
# Name: Status, Length: 215, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(AA,BB, train_size=0.6, random_state=16)
x_train
# Out:
#      Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 161            162       0               0              0         0
# 87              88       0               1              5         0
# 26              27       0               0              0         1
# 104            105       0               0              0         1
# 95              96       0               0              4         1
# ..             ...     ...             ...            ...       ...
# 123            124       0               0              0         1
# 65              66       0               0              4         0
# 69              70       0               1              4         1
# 121            122       1               0              4         1
# 169            170       0               0              4         0
#
#      Speacialisation  CGPA  Status  Package(LPA)  NOC  Skills  \
# 161                0     6       1             3   39       1
# ...

# %%
y_train
# Out:
# 161    1
# 87     1
# 26     0
# 104    0
# 95     0
#       ..
# 123    0
# 65     1
# 69     0
# 121    0
# 169    1
# Name: Status, Length: 129, dtype: int64

# %%
x_test
# Out:
#      Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 77              78       0               0              4         1
# 147            148       0               1              0         0
# 29              30       0               1              0         0
# 178            179       0               0              4         0
# 72              73       0               0              0         0
# ..             ...     ...             ...            ...       ...
# 151            152       0               1              0         0
# 66              67       0               0              0         0
# 82              83       0               1              0         0
# 112            113       0               0              3         0
# 105            106       0               0              4         0
#
#      Speacialisation  CGPA  Status  Package(LPA)  NOC  Skills  \
# 77                 1     5       0             2   32       2
# ...

# %%
y_test
# Out:
# 77     0
# 147    0
# 29     1
# 178    0
# 72     0
#       ..
# 151    0
# 66     0
# 82     1
# 112    0
# 105    1
# Name: Status, Length: 86, dtype: int64

# %% [markdown]
# ## **MODEL BUILDING**

# %% [markdown]
# #SVM Model

# %%
from sklearn.svm import SVC

# %%
svm= SVC(kernel='sigmoid', C=1.0)

# %%
svm.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
pred_test=svm.predict(x_test)
pred_train=svm.predict(x_train)

# %%
from sklearn.metrics import accuracy_score

# %%
train_accuracy=accuracy_score(pred_train,y_train)
test_accuracy=accuracy_score(pred_test,y_test)

# %%
print("accuracy on training data is ", train_accuracy)
print("accuracy on test data is ", test_accuracy)
# Out:
# accuracy on training data is  0.689922480620155
# accuracy on test data is  0.7325581395348837

# %%
df
# Out:
#      Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 0                1       0               0              3         0
# 1                2       0               0              0         1
# 2                3       0               1              3         0
# 3                4       0               1              0         0
# 4                5       0               1              2         0
# ..             ...     ...             ...            ...       ...
# 210            211       0               0              3         0
# 211            212       0               0              4         0
# 212            213       0               0              0         1
# 213            214       1               0              1         0
# 214            215       0               0              0         0
#
#      Speacialisation  CGPA  Status  Package(LPA)  NOC  Skills  \
# 0                  0     5       0             2   38       1
# ...

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
best_k = 0
best_score = 0
predictions_list = []

for k in range(3,20,1):
    knn_temp = KNeighborsClassifier(n_neighbors=k)
    knn_temp.fit(x_train, y_train)
    knn_temp_predict = knn_temp.predict(x_test)
    predictions_list.append(knn_temp_predict)

score = accuracy_score(y_test, knn_temp_predict)
if score > best_score and score < 100:
  best_score = score
  best_k = k
print("k =", best_k)
print("accuracy =", best_score)
# Out:
# k = 19
# accuracy = 0.7790697674418605

# %% [markdown]
# # Multivariate Graphs

# %% [markdown]
# Scatter plot

# %%
df.head()
# Out:
#    Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 0              1       0               0              3         0
# 1              2       0               0              0         1
# 2              3       0               1              3         0
# 3              4       0               1              0         0
# 4              5       0               1              2         0
#
#    Speacialisation  CGPA  Status  Package(LPA)  NOC  Skills  \
# 0                0     5       0             2   38       1
# 1                1     6       0             2   38       0
# 2                1     5       0             2   38       0
# 3                0     5       1             5   31       2
# 4                1     5       0             5   31       1
#
#    No_Of_Internships  total_percentage
# 0                  0                79
# 1                  1                78
# 2                  0                66
# 3                  1                54
# ...

# %%
plt.scatter(df['Status'],df['total_percentage'])
plt.xlabel('STATUS')
plt.ylabel('Total percentage')
# Out:
# Text(0, 0.5, 'Total percentage')

# %% [markdown]
# # Heatmap

# %%
plt.subplots(figsize=(15,13))
sns.heatmap(df,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Visualizing the performane of Classification model

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

# %%
df.head(20)
# Out:
#     Enrollment_no  Gender  Certifications  Degree_Stream  Work_Exp  \
# 0               1       0               0              3         0
# 1               2       0               0              0         1
# 2               3       0               1              3         0
# 3               4       0               1              0         0
# 4               5       0               1              2         0
# 5               6       0               0              1         1
# 6               7       1               0              2         0
# 7               8       0               1              4         1
# 8               9       0               1              0         0
# 9              10       0               1              4         0
# 10             11       0               1              0         1
# 11             12       0               1              1         1
# 12             13       1               0              5         0
# ...

# %%
true_labels=(df['Work_Exp'])
predicted_labels=df['Status']

# %%
cm = confusion_matrix(true_labels, predicted_labels)

# %%
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xticks([0, 1], ["Predicted Negative", "Predicted Positive"])
plt.yticks([0, 1], ["Actual Negative", "Actual Positive"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# # Creating Prediction Model For Interface

# %%
from sklearn.preprocessing import LabelEncoder

# %%
d = pd.DataFrame(df)

# %%
prediction_list = []
def prediction_model(input_data):
  knn_temp = KNeighborsClassifier(n_neighbors=k)
  knn_temp.fit(x_train, y_train)
  knn_temp_predict = knn_temp.predict(x_test)
  prediction_list.append(knn_temp_predict)

  if(prediction_list == 0):
     return "not placed"
  else:
     return "placed"

# %%
def preprocess_data(d):

  le = LabelEncoder()
  d["Gender"] = le.fit_transform(d["Gender"])
  d["Degree_Stream"] = le.fit_transform(d["Degree_Stream"])
  d["Speacialisation"] = le.fit_transform(d["Speacialisation"])


    # Selecting numeric columns for preprocessing
  numeric_columns = [ 'Enrollment_no', 'total_percentage', 'Package(LPA)']

    # Apply StandardScaler to numeric columns
  for col in numeric_columns:
    d[col] = ss.fit_transform(d[col].values.reshape(-1, 1))  # Reshape here

    return d

  input_data = d['Enrollment_no'],['Gender'],['Certifications'],['Degree_Stream'],['Work_Exp'],['Speacialisation'],['CGPA'],['Skills'],['No_Of_Internships'],['total_percentage']
  return input_data


inputs = [
    gr.components.Textbox(label="Enrollment_no"),
    gr.components.Dropdown(["M", "F"], label="Gender"),
    gr.components.Dropdown(["AWS Cloud Foundation", "PCAP : Python essential"],label="Certifications"),
    gr.components.Dropdown(["CS", "DS","AIML","CD","CD","IOT"], label="Degree_Stream"),
    gr.components.Dropdown(["Yes", "No"], label="Work_Exp"),
    gr.components.Dropdown(["5", "6","7"],label="CGPA"),
    gr.components.Dropdown(["C, Java", "C++, Python"],label="Speacialisation"),
    gr.components.Dropdown(["Cloud", "Big Data","Computer Networking","SQL"],label="Skills"),
    gr.components.Dropdown(["0", "1"],label="No_Of_Internships"),
    gr.components.Textbox(label="total_percentage"),


            ]

outputs = "text"

#face = gr.Interface(fn=prediction_model, inputs=inputs, outputs=outputs)

gr_interface = gr.Interface(
    fn=lambda Enrollment_no, Gender, Certifications, Degree_Stream, Work_Exp, Speacialisation, CGPA, Skills, No_Of_Internships, total_percentage:
       prediction_model(preprocess_data(d)),
    inputs=inputs,
    outputs=outputs,
    live=True
)

gr_interface.launch(debug = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:277: UserWarning: api_name predict already exists, using predict_1
#   warnings.warn(f"api_name {api_name} already exists, using {api_name_}")
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:277: UserWarning: api_name predict already exists, using predict_2
#   warnings.warn(f"api_name {api_name} already exists, using {api_name_}")
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:277: UserWarning: api_name predict already exists, using predict_3
#   warnings.warn(f"api_name {api_name} already exists, using {api_name_}")
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:277: UserWarning: api_name predict already exists, using predict_4
#   warnings.warn(f"api_name {api_name} already exists, using {api_name_}")
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:277: UserWarning: api_name predict already exists, using predict_5
# ...
